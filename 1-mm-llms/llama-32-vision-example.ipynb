# %% [markdown]
# # Exploring Llama 3.2-Vision (locally) with Ollama

# %%
#!pip install ollama

# %%
import ollama

# %% [markdown]
# ### pull model

# %%
ollama.pull('llama3.2-vision')
# Out:
# ProgressResponse(status='success', completed=None, total=None, digest=None)

# %% [markdown]
# #### Basic Usage

# %%
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['images/selfie.jpg']
    }]
)

print(response['message']['content'])
# Out:
# The image appears to be of a woman sitting at a table in a coffee shop or café. She is taking a photo of herself with her phone. The woman is wearing a red jacket and a white hat. The table she is sitting at has a coffee cup and a book on it.

# %% [markdown]
# #### Image captioning - streaming

# %%
stream = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'Can you write a caption for this image?',
        'images': ['images/selfie.jpg']
    }],
    stream=True,
)

for chunk in stream:
    print(chunk['message']['content'], end='', flush=True)
# Out:
# A woman sits at a table on an outdoor patio, taking a photo with her smartphone. She wears a red coat, white hat, and sunglasses, and has a coffee cup and a book on the table.

# %% [markdown]
# #### Explaining memes

# %%
stream = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'Can you explain this meme to me?',
        'images': ['images/ai-meme.jpeg']
    }],
    stream=True,
)

for chunk in stream:
    print(chunk['message']['content'], end='', flush=True)
# Out:
# The meme shows a character from SpongeBob SquarePants named Patrick Star, who is trying to build something with blocks on the beach. The blocks have various AI logos on them, like Google's Deep  and Meta’s LLa  . The image is meant to be funny because it shows how many different AI tools are out there and how they all want to be used to build something. The meme is meant to be funny and to make people think about how many different AI tools there are and how they all want to be used to build something.

# %% [markdown]
# #### OCR

# %%
stream = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'Can you transcribe the text from this screenshot in a markdown format?',
        'images': ['images/5-ai-projects.jpeg']
    }],
    stream=True,
)

for chunk in stream:
    print(chunk['message']['content'], end='', flush=True)
# Out:
# # 5 AI Projects You Can Build This Weekend (with Python)
# ## 1) Resume Optimization (Beginner)
# ### Idea: Build a tool that adapts your resume for a specific job description
#
# ## 2) YouTube Lecture Summarizer (Beginner)
# ### Idea: Build a tool that takes a YouTube video link and summarizes it
#
# ## 3) PDF Organizer (Intermediate)
# ### Idea: Build a tool to analyze the content of each PDF and organize them into f
